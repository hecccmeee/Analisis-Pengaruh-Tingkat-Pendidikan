# %% [markdown]
# <a href="https://colab.research.google.com/github/hecccmeee/Analisis-Pengaruh-Tingkat-Pendidikan/blob/main/projek_kelas_12_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## link data set
# https://www.kaggle.com/datasets/panjikumbara/dataset-pengangguran-indonesia-tingkat-pendidikan

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26156edb-45e6-4c77-a937-0f19a0612f48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26156edb-45e6-4c77-a937-0f19a0612f48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.listdir('/content/')
# Out:
# ['.config',
#  'archive (11).zip',
#  'archive (11) (2).zip',
#  'Data Training-1.csv',
#  'archive (11) (1).zip',
#  'archive (11) (3).zip',
#  'sample_data']

# %%
import zipfile

zip_file_path = '/content/archive (11).zip'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import pandas as pd

csv_file_path = '/content/Data Training-1.csv'

df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    Periode     Bulan  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# 0     2006  Februari                      234465                614960
# 1     2006   Agustus                      170666                611254
# 2     2007  Februari                      145750                520316
# 3     2007   Agustus                       94301                438519
# 4     2008  Februari                       79764                448431
#
#         SD     SLTP  SLTA Umum/SMU  SLTA Kejuruan/SMK  Akademi/Diploma  \
# 0  2675459  2860007        2842876            1204140           297185
# 1  2589699  2730045        2851518            1305190           278074
# 2  2753548  2643062        2630360            1114675           330316
# 3  2179792  2264198        2532204            1538349           397191
# 4  2216748  2166619        2204377            1165582           519867
#
#    Universitas     Total
# 0       375601  11104693
# 1       395554  10932000
# 2       409890  10547917
# ...

# %%
['.config', 'archive (11).zip', 'sample_data']
# Out:
# ['.config', 'archive (11).zip', 'sample_data']

# %%
df.info()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Periode                     35 non-null     int64
#  1   Bulan                       35 non-null     object
#  2   Tidak/belum pernah sekolah  35 non-null     int64
#  3   Tidak/belum tamat SD        35 non-null     int64
#  4   SD                          35 non-null     int64
#  5   SLTP                        35 non-null     int64
#  6   SLTA Umum/SMU               35 non-null     int64
#  7   SLTA Kejuruan/SMK           35 non-null     int64
#  8   Akademi/Diploma             35 non-null     int64
#  9   Universitas                 35 non-null     int64
#  10  Total                       35 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.1+ KB
# Periode                       0
# Bulan                         0
# ...

# %%
df.describe()
# Out:
#            Periode  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# count    35.000000                   35.000000             35.000000
# mean   2014.228571                83398.457143         496154.714286
# std       5.082182                53949.291460         105794.400661
# min    2006.000000                15206.000000         328781.000000
# 25%    2010.000000                38596.500000         422384.000000
# 50%    2014.000000                79764.000000         489152.000000
# 75%    2018.500000               107820.500000         579941.000000
# max    2022.000000               234465.000000         737610.000000
#
#                  SD          SLTP  SLTA Umum/SMU  SLTA Kejuruan/SMK  \
# count  3.500000e+01  3.500000e+01   3.500000e+01       3.500000e+01
# mean   1.462738e+06  1.697168e+06   2.153685e+06       1.422718e+06
# std    5.112940e+05  4.367373e+05   3.518458e+05       3.361657e+05
# min    8.657780e+05  1.137195e+06   1.546699e+06       8.473650e+05
# ...

# %% [markdown]
# ## Membuat histogram untuk setiap kolom numerik dalam dataset

# %%
import matplotlib.pyplot as plt

df.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# !pip install seaborn matplotlib

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=['float64', 'int64'])

correlation_matrix = numeric_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Antar Fitur')
plt.show()

# %%
df.columns
# Out:
# Index(['Periode', 'Bulan', 'Tidak/belum pernah sekolah',
#        'Tidak/belum tamat SD', 'SD', 'SLTP', 'SLTA Umum/SMU',
#        'SLTA Kejuruan/SMK', 'Akademi/Diploma', 'Universitas', 'Total'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Periode', 'Bulan', 'Tidak/belum pernah sekolah',
#        'Tidak/belum tamat SD', 'SD', 'SLTP', 'SLTA Umum/SMU',
#        'SLTA Kejuruan/SMK', 'Akademi/Diploma', 'Universitas', 'Total'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

X = df[['Tidak/belum pernah sekolah', 'Tidak/belum tamat SD', 'SD', 'SLTP', 'SLTA Umum/SMU', 'SLTA Kejuruan/SMK', 'Akademi/Diploma', 'Universitas']]  # Fitur
Y = df['Total']

model = LinearRegression()

model.fit(X, Y)

print(f'Koefisien Regresi: {model.coef_}')
print(f'Intercept: {model.intercept_}')
# Out:
# Koefisien Regresi: [0.9920959  0.99911683 1.00784945 0.99598261 1.00612987 0.98235688
#  0.97197754 1.03489762]
# Intercept: -6971.484099769965

# %%
import matplotlib.pyplot as plt

df['Total'].hist(bins=20, figsize=(10, 6))
plt.title('Distribusi Total')
plt.xlabel('Total')
plt.ylabel('Frekuensi')
plt.show()

# %%
import pandas as pd
data_frame = pd.read_csv('/content/Data Training-1.csv')
print(data_frame.head())
# Out:
#    Periode     Bulan  Tidak/belum pernah sekolah  Tidak/belum tamat SD  \
# 0     2006  Februari                      234465                614960
# 1     2006   Agustus                      170666                611254
# 2     2007  Februari                      145750                520316
# 3     2007   Agustus                       94301                438519
# 4     2008  Februari                       79764                448431
#
#         SD     SLTP  SLTA Umum/SMU  SLTA Kejuruan/SMK  Akademi/Diploma  \
# 0  2675459  2860007        2842876            1204140           297185
# 1  2589699  2730045        2851518            1305190           278074
# 2  2753548  2643062        2630360            1114675           330316
# 3  2179792  2264198        2532204            1538349           397191
# 4  2216748  2166619        2204377            1165582           519867
#
#    Universitas     Total
# 0       375601  11104693
# 1       395554  10932000
# 2       409890  10547917
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(data_frame['SD'], data_frame['Total'])

plt.title('Hubungan Antara SD dan Total')
plt.xlabel('Pendidikan SD')
plt.ylabel('Total')
plt.show()

# %%
print(data_frame.columns)
# Out:
# Index(['Periode', 'Bulan', 'Tidak/belum pernah sekolah',
#        'Tidak/belum tamat SD', 'SD', 'SLTP', 'SLTA Umum/SMU',
#        'SLTA Kejuruan/SMK', 'Akademi/Diploma', 'Universitas', 'Total'],
#       dtype='object')
